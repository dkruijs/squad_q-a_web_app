# %% [markdown]
# Data EDA and pre-processing analysis
# ------
# In this notebook, I will document my preliminary data exploration and analysis steps, that have lead to the final steps in my production source code. In order to efficiently perform the data engineering and feature engineering steps, and make informed decisions at the model training phase, some exploration is beneficial.
#
# Here, we are working with our training dataset, the file [train-v2.0.json](https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json) in the SQuAD dataset.

# %% [markdown]
# ### Library imports

# %%
import pprint
import os
import json
import numpy as np

# %% [markdown]
# ### Data ingest and EDA
# We load the data and explore the structure of each datapoint. Here I use 'datapoint' to actually refer to a small dataset consisting of Q&A combinations and their relevant context snippet (paragraph) relating to one Wikipedia article, such as the "iPod" article below.

# %%
input_filepath = "../data/raw"
in_file_name = "train-v2.0.json"
in_file = os.path.join(input_filepath, in_file_name)
with open(in_file) as f:
    train = json.load(f)
 
pp = pprint.PrettyPrinter()
pp.pprint(train['data'][3])
# Out:
# {'paragraphs': [{'context': 'The iPod is a line of portable media players and '
#                             'multi-purpose pocket computers designed and '
#                             'marketed by Apple Inc. The first line was '
#                             'released on October 23, 2001, about 8½ months '
#                             'after iTunes (Macintosh version) was released. '
#                             'The most recent iPod redesigns were announced on '
#                             'July 15, 2015. There are three current versions '
#                             'of the iPod: the ultra-compact iPod Shuffle, the '
#                             'compact iPod Nano and the touchscreen iPod Touch.',
#                  'qas': [{'answers': [{'answer_start': 105, 'text': 'Apple'}],
#                           'id': '56cc55856d243a140015ef0a',
#                           'is_impossible': False,
#                           'question': 'Which company produces the iPod?'},
#                          {'answers': [{'answer_start': 147,
#                                        'text': 'October 23, 2001'}],
#                           'id': '56cc55856d243a140015ef0b',
#                           'is_impossible': False,
#                           'question': 'When was the original iPod released?'},
#                          {'answers': [{'answer_start': 302, 'text': 'three'}],
#                           'id': '56cc55856d243a140015ef0c',
#                           'is_impossible': False,
#                           'question': 'How many different types of iPod are '
#                                       'currently available?'},
#                          {'answers': [{'answer_start': 22,
#                                        'text': 'portable media players'}],
#                           'id': '56cc55856d243a140015ef0d',
#                           'is_impossible': False,
#                           'question': 'What kind of device is the iPod?'},
#                          {'answers': [{'answer_start': 400,
#                                        'text': 'touchscreen'}],
#                           'id': '56cc55856d243a140015ef0e',
#                           'is_impossible': False,
#                           'question': 'The iPod Touch uses what kind of '
#                                       'interface?'},
#                          {'answers': [{'answer_start': 159, 'text': '2001'}],
#                           'id': '56ce726faab44d1400b88791',
#                           'is_impossible': False,
#                           'question': 'In what year was the first iPod '
#                                       'released?'},
#                          {'answers': [{'answer_start': 105, 'text': 'Apple'}],
#                           'id': '56ce726faab44d1400b88792',
#                           'is_impossible': False,
#                           'question': 'What company manufactures the iPod?'},
#                          {'answers': [{'answer_start': 156, 'text': '3'}],
#                           'id': '56ce726faab44d1400b88793',
#                           'is_impossible': False,
#                           'question': 'How many versions of the iPod currently '
#                                       'exist?'},
#                          {'answers': [{'answer_start': 361, 'text': 'Shuffle'}],
#                           'id': '56ce726faab44d1400b88794',
#                           'is_impossible': False,
#                           'question': 'Which is the smallest version of the '
#                                       'iPod?'},
#                          {'answers': [{'answer_start': 286, 'text': '2015'}],
#                           'id': '56ce726faab44d1400b88795',
#                           'is_impossible': False,
#                           'question': 'In what year was the iPod most recently '
#                                       'redesigned?'}]},
#                 {'context': 'Like other digital music players, iPods can serve '
#                             'as external data storage devices. Storage '
#                             'capacity varies by model, ranging from 2 GB for '
#                             'the iPod Shuffle to 128 GB for the iPod Touch '
#                             '(previously 160 GB for the iPod Classic, which is '
#                             'now discontinued).',
#                  'qas': [{'answers': [{'answer_start': 62,
#                                        'text': 'data storage'}],
#                           'id': '56cc55fa6d243a140015ef14',
#                           'is_impossible': False,
#                           'question': 'In addition to playing music, what '
#                                       'other function can the iPod perform?'},
#                          {'answers': [{'answer_start': 131, 'text': '2 GB'}],
#                           'id': '56cc55fa6d243a140015ef15',
#                           'is_impossible': False,
#                           'question': 'What is the smallest data capacity for '
#                                       'an iPod product?'},
#                          {'answers': [{'answer_start': 160, 'text': '128 GB'}],
#                           'id': '56cc55fa6d243a140015ef16',
#                           'is_impossible': False,
#                           'question': 'What is the largest data capacity for '
#                                       'an iPod product?'},
#                          {'answers': [{'answer_start': 144,
#                                        'text': 'iPod Shuffle'}],
#                           'id': '56cc55fa6d243a140015ef17',
#                           'is_impossible': False,
#                           'question': 'Which iPod product features the '
#                                       'smallest data storage capacity?'},
#                          {'answers': [{'answer_start': 175,
#                                        'text': 'iPod Touch'}],
#                           'id': '56cc55fa6d243a140015ef18',
#                           'is_impossible': False,
#                           'question': 'Which current iPod product features the '
#                                       'largest data storage capacity?'},
#                          {'answers': [{'answer_start': 131, 'text': '2 GB'}],
#                           'id': '56ce72ecaab44d1400b8879b',
#                           'is_impossible': False,
#                           'question': "What's the storage capacity of the iPod "
#                                       'Shuffle?'},
#                          {'answers': [{'answer_start': 160, 'text': '128 GB'}],
#                           'id': '56ce72ecaab44d1400b8879c',
#                           'is_impossible': False,
#                           'question': "What's the storage capacity for the "
#                                       'iPod Touch?'}]},
#                 {'context': "Apple's iTunes software (and other alternative "
#                             'software) can be used to transfer music, photos, '
#                             'videos, games, contact information, e-mail '
#                             'settings, Web bookmarks, and calendars, to the '
#                             'devices supporting these features from computers '
#                             'using certain versions of Apple Macintosh and '
#                             'Microsoft Windows operating systems.',
#                  'qas': [{'answers': [{'answer_start': 8, 'text': 'iTunes'}],
#                           'id': '56cc56856d243a140015ef1e',
#                           'is_impossible': False,
#                           'question': 'What Apple program is used to '
#                                       'communicate between computers and '
#                                       'portable devices?'},
#                          {'answers': [{'answer_start': 261,
#                                        'text': 'Apple Macintosh and Microsoft '
#                                                'Windows'}],
#                           'id': '56cc56856d243a140015ef1f',
#                           'is_impossible': False,
#                           'question': 'Which operating systems are compatible '
#                                       'with iTunes?'},
#                          {'answers': [{'answer_start': 8, 'text': 'iTunes'}],
#                           'id': '56ce732faab44d1400b8879f',
#                           'is_impossible': False,
#                           'question': "What's the name of the software used to "
#                                       'manage music and other media on Apple '
#                                       'devices?'}]},
#                 {'context': 'Before the release of iOS 5, the iPod branding '
#                             'was used for the media player included with the '
#                             'iPhone and iPad, a combination of the Music and '
#                             'Videos apps on the iPod Touch. As of iOS 5, '
#                             'separate apps named "Music" and "Videos" are '
#                             'standardized across all iOS-powered products. '
#                             'While the iPhone and iPad have essentially the '
#                             'same media player capabilities as the iPod line, '
#                             'they are generally treated as separate products. '
#                             'During the middle of 2010, iPhone sales overtook '
#                             'those of the iPod.',
#                  'qas': [{'answers': [{'answer_start': 98, 'text': 'one'}],
#                           'id': '56cc57466d243a140015ef24',
#                           'is_impossible': False,
#                           'question': 'Prior to iOS 5, how many apps were '
#                                       'required to play music and videos on '
#                                       'iPhone and iPad?'},
#                          {'answers': [{'answer_start': 95, 'text': 'iPhone'}],
#                           'id': '56cc57466d243a140015ef26',
#                           'is_impossible': False,
#                           'question': 'In mid-2010, which Apple device had '
#                                       'higher sales than iPod?'},
#                          {'answers': [{'answer_start': 22, 'text': 'iOS 5'}],
#                           'id': '56ce73d1aab44d1400b887ab',
#                           'is_impossible': False,
#                           'question': 'With what iOS release did Apple '
#                                       'standardize media apps on all their '
#                                       'products?'},
#                          {'answers': [{'answer_start': 444, 'text': '2010'}],
#                           'id': '56ce73d1aab44d1400b887ac',
#                           'is_impossible': False,
#                           'question': 'In what year did iPhone sales surpass '
#                                       'those of iPods?'},
#                          {'answers': [{'answer_start': 207,
#                                        'text': '"Music" and "Videos"'}],
#                           'id': '56ce73d1aab44d1400b887ad',
#                           'is_impossible': False,
#                           'question': 'What are the titles of the standard '
#                                       'media apps on current Apple devices?'}]},
#                 {'context': 'In mid-2015, a new model of the iPod Touch was '
#                             'announced by Apple, and was officially released '
#                             'on the Apple store on July 15, 2015. The sixth '
#                             'generation iPod Touch includes a wide variety of '
#                             'spec improvements such as the upgraded A8 '
#                             'processor and higher-quality screen. The core is '
#                             'over 5 times faster than previous models and is '
#                             'built to be roughly on par with the iPhone 5S. It '
#                             'is available in 5 different colors: Space grey, '
#                             'pink, gold, silver and Product (red).',
#                  'qas': [{'answers': [{'answer_start': 230, 'text': 'A8'}],
#                           'id': '56cc58436d243a140015ef2a',
#                           'is_impossible': False,
#                           'question': 'What processor model is used in the '
#                                       'iPod Touch?'},
#                          {'answers': [{'answer_start': 136, 'text': 'sixth'}],
#                           'id': '56cc58436d243a140015ef2c',
#                           'is_impossible': False,
#                           'question': 'Which generation of iPod Touch was made '
#                                       'availalbe in July of 2015?'},
#                          {'answers': [{'answer_start': 136, 'text': 'sixth'}],
#                           'id': '56ce750daab44d1400b887b1',
#                           'is_impossible': False,
#                           'question': "What's the most recent generation of "
#                                       'iPod Touch?'},
#                          {'answers': [{'answer_start': 7, 'text': '2015'}],
#                           'id': '56ce750daab44d1400b887b2',
#                           'is_impossible': False,
#                           'question': 'In what year was the most recent iPod '
#                                       'Touch released?'},
#                          {'answers': [{'answer_start': 230, 'text': 'A8'}],
#                           'id': '56ce750daab44d1400b887b3',
#                           'is_impossible': False,
#                           'question': 'What type of processor does the current '
#                                       'iPod Touch use?'},
#                          {'answers': [{'answer_start': 10, 'text': '5'}],
#                           'id': '56ce750daab44d1400b887b4',
#                           'is_impossible': False,
#                           'question': 'In how many colors is the current iPod '
#                                       'Touch available?'}]},
#                 {'context': 'Though the iPod was released in 2001, its price '
#                             'and Mac-only compatibility caused sales to be '
#                             'relatively slow until 2004. The iPod line came '
#                             'from Apple\'s "digital hub" category, when the '
#                             'company began creating software for the growing '
#                             'market of personal digital devices. Digital '
#                             'cameras, camcorders and organizers had '
#                             'well-established mainstream markets, but the '
#                             'company found existing digital music players "big '
#                             'and clunky or small and useless" with user '
#                             'interfaces that were "unbelievably awful," so '
#                             'Apple decided to develop its own. As ordered by '
#                             "CEO Steve Jobs, Apple's hardware engineering "
#                             'chief Jon Rubinstein assembled a team of '
#                             'engineers to design the iPod line, including '
#                             'hardware engineers Tony Fadell and Michael Dhuey, '
#                             'and design engineer Sir Jonathan Ive. Rubinstein '
#                             'had already discovered the Toshiba disk drive '
#                             'when meeting with an Apple supplier in Japan, and '
#                             'purchased the rights to it for Apple, and had '
#                             'also already worked out how the screen, battery, '
#                             'and other key elements would work. The aesthetic '
#                             'was inspired by the 1958 Braun T3 transistor '
#                             'radio designed by Dieter Rams, while the wheel '
#                             'based user interface was prompted by Bang & '
#                             "Olufsen's BeoCom 6000 telephone. The product "
#                             '("the Walkman of the twenty-first century" ) was '
#                             'developed in less than one year and unveiled on '
#                             'October 23, 2001. Jobs announced it as a '
#                             'Mac-compatible product with a 5 GB hard drive '
#                             'that put "1,000 songs in your pocket."',
#                  'qas': [{'answers': [{'answer_start': 32, 'text': '2001'}],
#                           'id': '56cc5f3f6d243a140015ef46',
#                           'is_impossible': False,
#                           'question': 'In what year was the iPod first '
#                                       'introduced?'},
#                          {'answers': [{'answer_start': 116, 'text': '2004'}],
#                           'id': '56cc5f3f6d243a140015ef47',
#                           'is_impossible': False,
#                           'question': 'In what year did iPod sales show '
#                                       'improvement?'},
#                          {'answers': [{'answer_start': 601,
#                                        'text': 'Jon Rubinstein'}],
#                           'id': '56cc5f3f6d243a140015ef48',
#                           'is_impossible': False,
#                           'question': 'Which Apple engineer led original iPod '
#                                       'design group?'},
#                          {'answers': [{'answer_start': 1045,
#                                        'text': 'Braun T3 transistor radio'}],
#                           'id': '56cc5f3f6d243a140015ef49',
#                           'is_impossible': False,
#                           'question': 'What radio was the primary inspiration '
#                                       'for the look of the iPod?'},
#                          {'answers': [{'answer_start': 1369, 'text': '5 GB'}],
#                           'id': '56cc5f3f6d243a140015ef4a',
#                           'is_impossible': False,
#                           'question': 'What was the storage capacity of the '
#                                       'first iPod?'},
#                          {'answers': [{'answer_start': 32, 'text': '2001'}],
#                           'id': '56ce75d4aab44d1400b887bd',
#                           'is_impossible': False,
#                           'question': 'in what year was the original iPod '
#                                       'released?'},
#                          {'answers': [{'answer_start': 1369, 'text': '5 GB'}],
#                           'id': '56ce75d4aab44d1400b887be',
#                           'is_impossible': False,
#                           'question': 'How large was the hard drive on the '
#                                       'original iPod?'},
#                          {'answers': [{'answer_start': 1203,
#                                        'text': 'the Walkman'}],
#                           'id': '56ce75d4aab44d1400b887bf',
#                           'is_impossible': False,
#                           'question': 'What other popular music player did '
#                                       'Apple compare their new product to?'},
#                          {'answers': [{'answer_start': 601,
#                                        'text': 'Jon Rubinstein'}],
#                           'id': '56ce75d4aab44d1400b887c0',
#                           'is_impossible': False,
#                           'question': "What is the name of Apple's hardware "
#                                       'engineering chief who helped design the '
#                                       'iPod?'},
#                          {'answers': [{'answer_start': 807, 'text': 'Toshiba'}],
#                           'id': '56ce75d4aab44d1400b887c1',
#                           'is_impossible': False,
#                           'question': 'Who manufactured the hard drives for '
#                                       'the first iPods?'}]},
#                 {'context': 'Apple did not develop the iPod software entirely '
#                             "in-house, instead using PortalPlayer's reference "
#                             'platform based on two ARM cores. The platform had '
#                             'rudimentary software running on a commercial '
#                             'microkernel embedded operating system. '
#                             'PortalPlayer had previously been working on an '
#                             'IBM-branded MP3 player with Bluetooth headphones. '
#                             'Apple contracted another company, Pixo, to help '
#                             'design and implement the user interface under the '
#                             'direct supervision of Steve Jobs. As development '
#                             'progressed, Apple continued to refine the '
#                             "software's look and feel. Starting with the iPod "
#                             'Mini, the Chicago font was replaced with Espy '
#                             'Sans. Later iPods switched fonts again to Podium '
#                             "Sans—a font similar to Apple's corporate font, "
#                             'Myriad. iPods with color displays then adopted '
#                             'some Mac OS X themes like Aqua progress bars, and '
#                             'brushed metal meant to evoke a combination lock. '
#                             'In 2007, Apple modified the iPod interface again '
#                             'with the introduction of the sixth-generation '
#                             'iPod Classic and third-generation iPod Nano by '
#                             'changing the font to Helvetica and, in most '
#                             'cases, splitting the screen in half by displaying '
#                             'the menus on the left and album artwork, photos, '
#                             'or videos on the right (whichever was appropriate '
#                             'for the selected item).',
#                  'qas': [{'answers': [{'answer_start': 363, 'text': 'Pixo'}],
#                           'id': '56cc60186d243a140015ef5a',
#                           'is_impossible': False,
#                           'question': 'Which company worked with Apple in '
#                                       'creating the user interface for the '
#                                       'iPod?'},
#                          {'answers': [{'answer_start': 577, 'text': 'Chicago'}],
#                           'id': '56cc60186d243a140015ef5b',
#                           'is_impossible': False,
#                           'question': 'What was the name of the font used '
#                                       'prior to the release of the iPod Mini?'},
#                          {'answers': [{'answer_start': 858, 'text': '2007'}],
#                           'id': '56cc60186d243a140015ef5c',
#                           'is_impossible': False,
#                           'question': 'In what year was the 6th gen iPod '
#                                       'Classic released?'},
#                          {'answers': [{'answer_start': 1018,
#                                        'text': 'Helvetica'}],
#                           'id': '56cc60186d243a140015ef5d',
#                           'is_impossible': False,
#                           'question': 'The 6th gen iPod Classic and 3rd gen '
#                                       'iPod nano featured which font?'},
#                          {'answers': [{'answer_start': 449,
#                                        'text': 'Steve Jobs'}],
#                           'id': '56ce78c5aab44d1400b887d1',
#                           'is_impossible': False,
#                           'question': 'Who supervised the design and '
#                                       'implementation of the iPod user '
#                                       'interface?'},
#                          {'answers': [{'answer_start': 73,
#                                        'text': 'PortalPlayer'}],
#                           'id': '56ce78c5aab44d1400b887d2',
#                           'is_impossible': False,
#                           'question': 'What software did Apple use as the '
#                                       'basis for their iPod software?'},
#                          {'answers': [{'answer_start': 1018,
#                                        'text': 'Helvetica'}],
#                           'id': '56ce78c5aab44d1400b887d3',
#                           'is_impossible': False,
#                           'question': 'What typeface does the current iPod '
#                                       'use?'}]},
#                 {'context': 'In 2006 Apple presented a special edition for '
#                             'iPod 5G of Irish rock band U2. Like its '
#                             'predecessor, this iPod has engraved the '
#                             'signatures of the four members of the band on its '
#                             'back, but this one was the first time the company '
#                             'changed the colour of the metal (not silver but '
#                             'black). This iPod was only available with 30GB of '
#                             'storage capacity. The special edition entitled '
#                             'purchasers to an exclusive video with 33 minutes '
#                             'of interviews and performance by U2, downloadable '
#                             'from the iTunes Store.',
#                  'qas': [{'answers': [{'answer_start': 3, 'text': '2006'}],
#                           'id': '56cc60a36d243a140015ef64',
#                           'is_impossible': False,
#                           'question': 'In what year was a special edition of '
#                                       'the iPod produced?'},
#                          {'answers': [{'answer_start': 73, 'text': 'U2'}],
#                           'id': '56cc60a36d243a140015ef65',
#                           'is_impossible': False,
#                           'question': 'For what musical group was a special '
#                                       'edition of the iPod first made?'},
#                          {'answers': [{'answer_start': 274, 'text': 'black'}],
#                           'id': '56cc60a36d243a140015ef66',
#                           'is_impossible': False,
#                           'question': 'What color was the metal on the U2 '
#                                       'version of the iPod?'},
#                          {'answers': [{'answer_start': 398, 'text': 'video'}],
#                           'id': '56cc60a36d243a140015ef67',
#                           'is_impossible': False,
#                           'question': 'What type of media was included with '
#                                       'purchase of the U2 version of the '
#                                       'iPod?'},
#                          {'answers': [{'answer_start': 73, 'text': 'U2'}],
#                           'id': '56ce792caab44d1400b887d7',
#                           'is_impossible': False,
#                           'question': 'Of what band did Apple present a '
#                                       'special edition iPod 5G?'},
#                          {'answers': [{'answer_start': 274, 'text': 'black'}],
#                           'id': '56ce792caab44d1400b887d8',
#                           'is_impossible': False,
#                           'question': 'What color was the special U2 iPod '
#                                       'model?'},
#                          {'answers': [{'answer_start': 3, 'text': '2006'}],
#                           'id': '56ce792caab44d1400b887d9',
#                           'is_impossible': False,
#                           'question': 'In what year did apple release the '
#                                       'special U2 model of the iPod?'}]},
#                 {'context': 'In September 2007, during a lawsuit with patent '
#                             'holding company Burst.com, Apple drew attention '
#                             'to a patent for a similar device that was '
#                             'developed in 1979. Kane Kramer applied for a UK '
#                             'patent for his design of a "plastic music box" in '
#                             '1981, which he called the IXI. He was unable to '
#                             'secure funding to renew the US$120,000 worldwide '
#                             'patent, so it lapsed and Kramer never profited '
#                             'from his idea.',
#                  'qas': [{'answers': [{'answer_start': 64,
#                                        'text': 'Burst.com'}],
#                           'id': '56cc61346d243a140015ef6e',
#                           'is_impossible': False,
#                           'question': 'Apple was involved in a lawsuit with '
#                                       'which company in 2007?'},
#                          {'answers': [{'answer_start': 157,
#                                        'text': 'Kane Kramer'}],
#                           'id': '56cc61346d243a140015ef6f',
#                           'is_impossible': False,
#                           'question': 'Who previously applied for a patent for '
#                                       'an iPod-like device?'},
#                          {'answers': [{'answer_start': 183, 'text': 'UK'}],
#                           'id': '56cc61346d243a140015ef70',
#                           'is_impossible': False,
#                           'question': 'In what country did Kane Kramer apply '
#                                       'for his patent?'},
#                          {'answers': [{'answer_start': 236, 'text': '1981'}],
#                           'id': '56cc61346d243a140015ef71',
#                           'is_impossible': False,
#                           'question': 'In what year did Kane Kramer apply for '
#                                       'his patent?'},
#                          {'answers': [{'answer_start': 262, 'text': 'IXI'}],
#                           'id': '56cc61346d243a140015ef72',
#                           'is_impossible': False,
#                           'question': 'What did Kane Kramer call the device '
#                                       'for which he wanted a patent?'},
#                          {'answers': [{'answer_start': 64,
#                                        'text': 'Burst.com'}],
#                           'id': '56ce7ae2aab44d1400b887e7',
#                           'is_impossible': False,
#                           'question': 'What patent holding company sued Apple '
#                                       'in 2007?'},
#                          {'answers': [{'answer_start': 262, 'text': 'IXI'}],
#                           'id': '56ce7ae2aab44d1400b887e8',
#                           'is_impossible': False,
#                           'question': 'What was the name of the '
#                                       'previously-patented music player from '
#                                       '1981?'},
#                          {'answers': [{'answer_start': 157,
#                                        'text': 'Kane Kramer'}],
#                           'id': '56ce7ae2aab44d1400b887e9',
#                           'is_impossible': False,
#                           'question': 'Who was the holder of the previous '
#                                       'patent for the "plastic music box"?'}]},
#                 {'context': 'The name iPod was proposed by Vinnie Chieco, a '
#                             'freelance copywriter, who (with others) was '
#                             'called by Apple to figure out how to introduce '
#                             'the new player to the public. After Chieco saw a '
#                             'prototype, he thought of the movie 2001: A Space '
#                             'Odyssey and the phrase "Open the pod bay door, '
#                             'Hal!", which refers to the white EVA Pods of the '
#                             'Discovery One spaceship. Chieco saw an analogy to '
#                             'the relationship between the spaceship and the '
#                             'smaller independent pods in the relationship '
#                             'between a personal computer and the music player. '
#                             'Apple researched the trademark and found that it '
#                             'was already in use. Joseph N. Grasso of New '
#                             'Jersey had originally listed an "iPod" trademark '
#                             'with the U.S. Patent and Trademark Office (USPTO) '
#                             'in July 2000 for Internet kiosks. The first iPod '
#                             'kiosks had been demonstrated to the public in New '
#                             'Jersey in March 1998, and commercial use began in '
#                             'January 2000, but had apparently been '
#                             'discontinued by 2001. The trademark was '
#                             'registered by the USPTO in November 2003, and '
#                             'Grasso assigned it to Apple Computer, Inc. in '
#                             '2005.',
#                  'qas': [{'answers': [{'answer_start': 30,
#                                        'text': 'Vinnie Chieco'}],
#                           'id': '56cc62406d243a140015ef78',
#                           'is_impossible': False,
#                           'question': "Who came up with the name for Apple's "
#                                       'portable mp3 player?'},
#                          {'answers': [{'answer_start': 47,
#                                        'text': 'freelance copywriter'}],
#                           'id': '56cc62406d243a140015ef79',
#                           'is_impossible': False,
#                           'question': "What was Vinnie Chieco's profession?"},
#                          {'answers': [{'answer_start': 222,
#                                        'text': '2001: A Space Odyssey'}],
#                           'id': '56cc62406d243a140015ef7a',
#                           'is_impossible': False,
#                           'question': 'What film inspired the name of the '
#                                       'iPod?'},
#                          {'answers': [{'answer_start': 593,
#                                        'text': 'Joseph N. Grasso'}],
#                           'id': '56cc62406d243a140015ef7b',
#                           'is_impossible': False,
#                           'question': 'Who first trademarked the iPod name?'},
#                          {'answers': [{'answer_start': 1035, 'text': '2005'}],
#                           'id': '56cc62406d243a140015ef7c',
#                           'is_impossible': False,
#                           'question': 'In what year was Apple given rights to '
#                                       'the iPod name?'},
#                          {'answers': [{'answer_start': 222,
#                                        'text': '2001: A Space Odyssey'}],
#                           'id': '56ce7bf4aab44d1400b887f3',
#                           'is_impossible': False,
#                           'question': 'What movie inspired the iPod name?'},
#                          {'answers': [{'answer_start': 30,
#                                        'text': 'Vinnie Chieco'}],
#                           'id': '56ce7bf4aab44d1400b887f4',
#                           'is_impossible': False,
#                           'question': 'What was the name of the copywriter '
#                                       'that proposed the name "iPod"?'},
#                          {'answers': [{'answer_start': 593,
#                                        'text': 'Joseph N. Grasso'}],
#                           'id': '56ce7bf4aab44d1400b887f5',
#                           'is_impossible': False,
#                           'question': 'Who held the original trademark for the '
#                                       'iPod name?'}]},
#                 {'context': 'In mid-2015, several new color schemes for all of '
#                             'the current iPod models were spotted in the '
#                             'latest version of iTunes, 12.2. Belgian website '
#                             'Belgium iPhone originally found the images when '
#                             'plugging in an iPod for the first time, and '
#                             'subsequent leaked photos were found by Pierre '
#                             'Dandumont.',
#                  'qas': [{'answers': [{'answer_start': 3, 'text': 'mid-2015'}],
#                           'id': '56cc62ce6d243a140015ef82',
#                           'is_impossible': False,
#                           'question': 'When were images of new iPod colors '
#                                       'leaked?'},
#                          {'answers': [{'answer_start': 273,
#                                        'text': 'Pierre Dandumont'}],
#                           'id': '56cc62ce6d243a140015ef83',
#                           'is_impossible': False,
#                           'question': 'Who leaked the photos of new iPod '
#                                       'colors?'},
#                          {'answers': [{'answer_start': 120, 'text': '12.2'}],
#                           'id': '56cc62ce6d243a140015ef84',
#                           'is_impossible': False,
#                           'question': 'What version of iTunes contained the '
#                                       'leaked photos of new iPod colors?'},
#                          {'answers': [{'answer_start': 120, 'text': '12.2'}],
#                           'id': '56ce7c4baab44d1400b887fd',
#                           'is_impossible': False,
#                           'question': 'What was the latest version of iTunes '
#                                       'as of mid-2015?'},
#                          {'answers': [{'answer_start': 273,
#                                        'text': 'Pierre Dandumont'}],
#                           'id': '56ce7c4baab44d1400b887fe',
#                           'is_impossible': False,
#                           'question': 'Who first leaked the photos of the new '
#                                       'iPod color scheme?'}]},
#                 {'context': 'The third-generation iPod had a weak bass '
#                             'response, as shown in audio tests. The '
#                             'combination of the undersized DC-blocking '
#                             'capacitors and the typical low-impedance of most '
#                             'consumer headphones form a high-pass filter, '
#                             'which attenuates the low-frequency bass output. '
#                             'Similar capacitors were used in the '
#                             'fourth-generation iPods. The problem is reduced '
#                             'when using high-impedance headphones and is '
#                             'completely masked when driving high-impedance '
#                             '(line level) loads, such as an external headphone '
#                             'amplifier. The first-generation iPod Shuffle uses '
#                             'a dual-transistor output stage, rather than a '
#                             'single capacitor-coupled output, and does not '
#                             'exhibit reduced bass response for any load.',
#                  'qas': [{'answers': [{'answer_start': 32,
#                                        'text': 'weak bass response'}],
#                           'id': '56cc643d6d243a140015ef88',
#                           'is_impossible': False,
#                           'question': 'What audio deficiency was found in the '
#                                       '3rd gen iPods?'},
#                          {'answers': [{'answer_start': 360,
#                                        'text': 'high-impedance'}],
#                           'id': '56cc643d6d243a140015ef8a',
#                           'is_impossible': False,
#                           'question': 'What kind of headphones could partially '
#                                       'mitigate the bass response issues of '
#                                       'the 3rd gen iPods?'},
#                          {'answers': [{'answer_start': 470,
#                                        'text': 'external headphone amplifier'}],
#                           'id': '56cc643d6d243a140015ef8b',
#                           'is_impossible': False,
#                           'question': 'What is an example of a device that '
#                                       'could entirely mitigate the bass '
#                                       'response issues of the 3rd gen iPods?'},
#                          {'answers': [{'answer_start': 37, 'text': 'bass'}],
#                           'id': '56ce81bdaab44d1400b88817',
#                           'is_impossible': False,
#                           'question': 'What part of audio output was '
#                                       'substandard on 3rd generation iPods?'},
#                          {'answers': [{'answer_start': 100,
#                                        'text': 'undersized DC-blocking '
#                                                'capacitors'}],
#                           'id': '56ce81bdaab44d1400b88818',
#                           'is_impossible': False,
#                           'question': 'What component was to blame for the '
#                                       'weak bass of the 3rd generation '
#                                       'iPod?'}]},
#                 {'context': 'For all iPods released in 2006 and earlier, some '
#                             'equalizer (EQ) sound settings would distort the '
#                             'bass sound far too easily, even on undemanding '
#                             'songs. This would happen for EQ settings like '
#                             'R&B, Rock, Acoustic, and Bass Booster, because '
#                             'the equalizer amplified the digital audio level '
#                             "beyond the software's limit, causing distortion "
#                             '(clipping) on bass instruments.',
#                  'qas': [{'answers': [{'answer_start': 215, 'text': 'Bass'}],
#                           'id': '56cc655c6d243a140015ef92',
#                           'is_impossible': False,
#                           'question': 'What acoustic element could be '
#                                       'distorted by different audio settings '
#                                       'in iPods prior to 2007?'},
#                          {'answers': [{'answer_start': 190,
#                                        'text': 'R&B, Rock, Acoustic, and Bass '
#                                                'Booster'}],
#                           'id': '56cc655c6d243a140015ef93',
#                           'is_impossible': False,
#                           'question': 'Name four sound profiles that would '
#                                       'result in bass distortion on pre-2007 '
#                                       'iPods.'},
#                          {'answers': [{'answer_start': 334,
#                                        'text': 'clipping'}],
#                           'id': '56cc655c6d243a140015ef94',
#                           'is_impossible': False,
#                           'question': 'What specific problem caused the issue '
#                                       'with bass distortion?'},
#                          {'answers': [{'answer_start': 26, 'text': '2006'}],
#                           'id': '56ce8214aab44d1400b88823',
#                           'is_impossible': False,
#                           'question': 'iPods released before what year had '
#                                       'issues with distorted bass?'},
#                          {'answers': [{'answer_start': 190,
#                                        'text': 'R&B, Rock, Acoustic, and Bass '
#                                                'Booster'}],
#                           'id': '56ce8214aab44d1400b88824',
#                           'is_impossible': False,
#                           'question': 'What EQ settings were known to have '
#                                       'issues with bass distortion?'}]},
#                 {'context': 'From the fifth-generation iPod on, Apple '
#                             'introduced a user-configurable volume limit in '
#                             'response to concerns about hearing loss. Users '
#                             'report that in the sixth-generation iPod, the '
#                             'maximum volume output level is limited to 100 dB '
#                             'in EU markets. Apple previously had to remove '
#                             'iPods from shelves in France for exceeding this '
#                             'legal limit. However, users that have bought a '
#                             'new sixth-generation iPod in late 2013 have '
#                             'reported a new option that allowed them to '
#                             'disable the EU volume limit. It has been said '
#                             'that these new iPods came with an updated '
#                             'software that allowed this change. Older '
#                             'sixth-generation iPods, however, are unable to '
#                             'update to this software version.',
#                  'qas': [{'answers': [{'answer_start': 115,
#                                        'text': 'hearing loss'}],
#                           'id': '56cc66326d243a140015ef98',
#                           'is_impossible': False,
#                           'question': 'What type of sensory issue was a '
#                                       'concern prior to the release of 5th gen '
#                                       'iPods?'},
#                          {'answers': [{'answer_start': 233, 'text': 'EU'}],
#                           'id': '56cc66326d243a140015ef99',
#                           'is_impossible': False,
#                           'question': 'In what markets did 6th gen iPods limit '
#                                       'the highest volume of the player?'},
#                          {'answers': [{'answer_start': 223, 'text': '100 dB'}],
#                           'id': '56cc66326d243a140015ef9a',
#                           'is_impossible': False,
#                           'question': 'What was the limit imposed on how loud '
#                                       'the iPod could play sounds in the EU?'},
#                          {'answers': [{'answer_start': 298, 'text': 'France'}],
#                           'id': '56cc66326d243a140015ef9b',
#                           'is_impossible': False,
#                           'question': 'In what country did Apple have to '
#                                       'recall iPods?'},
#                          {'answers': [{'answer_start': 223, 'text': '100 dB'}],
#                           'id': '56ce829baab44d1400b88828',
#                           'is_impossible': False,
#                           'question': 'What is the highest volume output level '
#                                       'of European 6th-generation iPods?'},
#                          {'answers': [{'answer_start': 298, 'text': 'France'}],
#                           'id': '56ce829baab44d1400b88829',
#                           'is_impossible': False,
#                           'question': 'What country originally pulled iPods '
#                                       'due to higher-than-allowed volume '
#                                       'levels?'}]},
#                 {'context': 'Originally, a FireWire connection to the host '
#                             'computer was used to update songs or recharge the '
#                             'battery. The battery could also be charged with a '
#                             'power adapter that was included with the first '
#                             'four generations.',
#                  'qas': [{'answers': [{'answer_start': 14, 'text': 'FireWire'}],
#                           'id': '56cc66d16d243a140015efa2',
#                           'is_impossible': False,
#                           'question': 'What was the first type of connection '
# ...
#                                       'iPod Nanos which suffered from '
#                                       'overheating problems with new safe '
#                                       'models?'}]},
#                 {'context': 'iPods have been criticized for alleged short '
#                             'life-span and fragile hard drives. A 2005 survey '
#                             'conducted on the MacInTouch website found that '
#                             'the iPod line had an average failure rate of '
#                             '13.7% (although they note that comments from '
#                             'respondents indicate that "the true iPod failure '
#                             'rate may be lower than it appears"). It concluded '
#                             'that some models were more durable than others. '
#                             'In particular, failure rates for iPods employing '
#                             'hard drives was usually above 20% while those '
#                             'with flash memory had a failure rate below 10%. '
#                             'In late 2005, many users complained that the '
#                             'surface of the first generation iPod Nano can '
#                             'become scratched easily, rendering the screen '
#                             'unusable. A class action lawsuit was also filed. '
#                             'Apple initially considered the issue a minor '
#                             'defect, but later began shipping these iPods with '
#                             'protective sleeves.[citation needed]',
#                  'qas': [{'answers': [{'answer_start': 39,
#                                        'text': 'short life-span and fragile '
#                                                'hard drives'}],
#                           'id': '56cd7ef762d2951400fa6652',
#                           'is_impossible': False,
#                           'question': 'What are two subjects of criticism of '
#                                       'iPods?'},
#                          {'answers': [{'answer_start': 111,
#                                        'text': 'MacInTouch'}],
#                           'id': '56cd7ef762d2951400fa6653',
#                           'is_impossible': False,
#                           'question': 'What website ran a survey to learn how '
#                                       'often iPods ceased working?'},
#                          {'answers': [{'answer_start': 186, 'text': '13.7%'}],
#                           'id': '56cd7ef762d2951400fa6654',
#                           'is_impossible': False,
#                           'question': 'How often did MacInTouch discover iPods '
#                                       'stopped working, according to their '
#                                       'survey?'},
#                          {'answers': [{'answer_start': 524,
#                                        'text': 'late 2005'}],
#                           'id': '56cd7ef762d2951400fa6655',
#                           'is_impossible': False,
#                           'question': 'When did iPod owners take issue with '
#                                       'the fragility of the iPod screen?'},
#                          {'answers': [{'answer_start': 802,
#                                        'text': 'protective sleeves'}],
#                           'id': '56cd7ef762d2951400fa6656',
#                           'is_impossible': False,
#                           'question': 'What did Apple include with the iPod to '
#                                       'resolve the screen problem?'},
#                          {'answers': [{'answer_start': 478,
#                                        'text': 'flash memory'}],
#                           'id': '56d133d517492d1400aabc2b',
#                           'is_impossible': False,
#                           'question': 'Which type of iPod storage proved more '
#                                       'reliable than hard drive storage?'},
#                          {'answers': [{'answer_start': 651, 'text': 'screen'}],
#                           'id': '56d133d517492d1400aabc2c',
#                           'is_impossible': False,
#                           'question': 'The first generation nano suffered from '
#                                       'which component getting damaged '
#                                       'easily?'}]},
#                 {'context': 'On June 11, 2006, the British tabloid The Mail on '
#                             'Sunday reported that iPods are mainly '
#                             'manufactured by workers who earn no more than '
#                             'US$50 per month and work 15-hour shifts. Apple '
#                             'investigated the case with independent auditors '
#                             "and found that, while some of the plant's labour "
#                             "practices met Apple's Code of Conduct, others did "
#                             'not: employees worked over 60 hours a week for '
#                             '35% of the time, and worked more than six '
#                             'consecutive days for 25% of the time.',
#                  'qas': [{'answers': [{'answer_start': 38,
#                                        'text': 'The Mail on Sunday'}],
#                           'id': '56cd7f9162d2951400fa665c',
#                           'is_impossible': False,
#                           'question': 'What publication revealed information '
#                                       'about the working conditions of iPod '
#                                       'labor?'},
#                          {'answers': [{'answer_start': 292,
#                                        'text': "Apple's Code of Conduct"}],
#                           'id': '56cd7f9162d2951400fa665f',
#                           'is_impossible': False,
#                           'question': "What governs iPod manufacturers' labor "
#                                       'policies?'},
#                          {'answers': [{'answer_start': 438, 'text': '25'}],
#                           'id': '56cd7f9162d2951400fa6660',
#                           'is_impossible': False,
#                           'question': 'What percentage of the time did The '
#                                       'Mail on Sunday claim workers labored '
#                                       'for at least seven straight days?'},
#                          {'answers': [{'answer_start': 38, 'text': 'The Mail'}],
#                           'id': '56d13443e7d4791d00901feb',
#                           'is_impossible': False,
#                           'question': 'Which British tabloid accused Apple of '
#                                       'unfair worker conditions in 2006?'},
#                          {'answers': [{'answer_start': 375, 'text': '35%'}],
#                           'id': '56d13443e7d4791d00901fec',
#                           'is_impossible': False,
#                           'question': "What percentage of Apple's "
#                                       'manufacturing employees worked over 60 '
#                                       'hour weeks?'}]},
#                 {'context': "Foxconn, Apple's manufacturer, initially denied "
#                             'the abuses, but when an auditing team from Apple '
#                             'found that workers had been working longer hours '
#                             'than were allowed under Chinese law, they '
#                             'promised to prevent workers working more hours '
#                             'than the code allowed. Apple hired a workplace '
#                             'standards auditing company, Verité, and joined '
#                             'the Electronic Industry Code of Conduct '
#                             'Implementation Group to oversee the measures. On '
#                             'December 31, 2006, workers at the Foxconn factory '
#                             'in Longhua, Shenzhen formed a union affiliated '
#                             'with the All-China Federation of Trade Unions, '
#                             'the Chinese government-approved union umbrella '
#                             'organization.',
#                  'qas': [{'answers': [{'answer_start': 310, 'text': 'Verité'}],
#                           'id': '56cd81df62d2951400fa6666',
#                           'is_impossible': False,
#                           'question': 'Who did Apple partner with to monitor '
#                                       'its labor policies?'},
#                          {'answers': [{'answer_start': 333,
#                                        'text': 'Electronic Industry Code of '
#                                                'Conduct Implementation Group'}],
#                           'id': '56cd81df62d2951400fa6667',
#                           'is_impossible': False,
#                           'question': 'What organization did Apple join to '
#                                       'monitor its labor policies?'},
#                          {'answers': [{'answer_start': 0, 'text': 'Foxconn'}],
#                           'id': '56cd81df62d2951400fa6668',
#                           'is_impossible': False,
#                           'question': 'What company was found to be violating '
#                                       "Apple's labor policies?"},
#                          {'answers': [{'answer_start': 471,
#                                        'text': 'Longhua, Shenzhen'}],
#                           'id': '56cd81df62d2951400fa6669',
#                           'is_impossible': False,
#                           'question': 'Where was the Foxconn plant located?'},
#                          {'answers': [{'answer_start': 0, 'text': 'Foxconn'}],
#                           'id': '56d134c2e7d4791d00901ff7',
#                           'is_impossible': False,
#                           'question': "What was the name of Apple's "
#                                       'manufacturing company that was accused '
#                                       'of overworking its employees?'},
#                          {'answers': [{'answer_start': 310, 'text': 'Verité'}],
#                           'id': '56d134c2e7d4791d00901ff8',
#                           'is_impossible': False,
#                           'question': 'What auditor company did Apple hire to '
#                                       'oversee worker conditions following the '
#                                       'controversy?'},
#                          {'answers': [{'answer_start': 431, 'text': '2006'}],
#                           'id': '56d134c2e7d4791d00901ff9',
#                           'is_impossible': False,
#                           'question': 'In what year did Foxconn workers first '
#                                       'unionize?'}]},
#                 {'context': 'In 2010, a number of workers committed suicide at '
#                             'a Foxconn operations in China. Apple, HP, and '
#                             'others stated that they were investigating the '
#                             'situation. Foxconn guards have been videotaped '
#                             'beating employees. Another employee killed '
#                             'himself in 2009 when an Apple prototype went '
#                             'missing, and claimed in messages to friends, that '
#                             'he had been beaten and interrogated.',
#                  'qas': [{'answers': [{'answer_start': 3, 'text': '2010'}],
#                           'id': '56cd828562d2951400fa6670',
#                           'is_impossible': False,
#                           'question': 'In what year did Chinese Foxconn '
#                                       'emplyees kill themselves?'},
#                          {'answers': [{'answer_start': 257,
#                                        'text': 'Apple prototype'}],
#                           'id': '56cd828562d2951400fa6672',
#                           'is_impossible': False,
#                           'question': 'What disappeared in 2009 prior to the '
#                                       'suicide of a Foxconn employee?'},
#                          {'answers': [{'answer_start': 3, 'text': '2010'}],
#                           'id': '56d13543e7d4791d00902004',
#                           'is_impossible': False,
#                           'question': 'In what year did several Foxconn '
#                                       'workers commit suicide?'}]},
#                 {'context': 'As of 2006, the iPod was produced by about 14,000 '
#                             'workers in the U.S. and 27,000 overseas. Further, '
#                             'the salaries attributed to this product were '
#                             'overwhelmingly distributed to highly skilled U.S. '
#                             'professionals, as opposed to lower skilled U.S. '
#                             'retail employees or overseas manufacturing labor. '
#                             'One interpretation of this result is that U.S. '
#                             'innovation can create more jobs overseas than '
#                             'domestically.',
#                  'qas': [{'answers': [{'answer_start': 340,
#                                        'text': 'innovation'}],
#                           'id': '56cd834d62d2951400fa668a',
#                           'is_impossible': False,
#                           'question': 'What attribute of the United States '
#                                       'could be thought to lead more '
#                                       'international and less domestic '
#                                       'employment opportunities?'}]},
#                 {'context': 'All iPods except for the iPod Touch can function '
#                             'in "disk mode" as mass storage devices to store '
#                             'data files but this may not be the default '
#                             'behavior, and in the case of the iPod Touch, '
#                             'requires special software.[citation needed] If an '
#                             'iPod is formatted on a Mac OS computer, it uses '
#                             'the HFS+ file system format, which allows it to '
#                             'serve as a boot disk for a Mac computer. If it is '
#                             'formatted on Windows, the FAT32 format is used. '
#                             'With the release of the Windows-compatible iPod, '
#                             'the default file system used on the iPod line '
#                             'switched from HFS+ to FAT32, although it can be '
#                             'reformatted to either file system (excluding the '
#                             'iPod Shuffle which is strictly FAT32). Generally, '
#                             'if a new iPod (excluding the iPod Shuffle) is '
#                             'initially plugged into a computer running '
#                             'Windows, it will be formatted with FAT32, and if '
#                             'initially plugged into a Mac running Mac OS it '
#                             'will be formatted with HFS+.',
#                  'qas': [{'answers': [{'answer_start': 287, 'text': 'HFS+'}],
#                           'id': '56cfc488234ae51400d9bf47',
#                           'is_impossible': False,
#                           'question': 'To work as a boot disk for a Mac, what '
#                                       'file system must an iPod be formatted '
#                                       'with?'},
#                          {'answers': [{'answer_start': 407, 'text': 'FAT32'}],
#                           'id': '56cfc488234ae51400d9bf48',
#                           'is_impossible': False,
#                           'question': 'If connected to a Windows PC when first '
#                                       'set up, what file system will an iPod '
#                                       'be formatted with?'}]}],
#  'title': 'IPod'}

# %% [markdown]
# Here, we see that each dataset consists of a `title` field (here, "Ipod"), a list of `paragraph` fields, and each paragraph contains the paragraph's text under `context` and a set of questions and answers, under `qas`. Per QA-set we have an ID field, data on the starting character of the text span that contains the answer (`answer_start`), the ground truth answer text itself (`text`) and whether or not the question is impossible to answer (`is_impossible`).
#
#
# **Questions we want to answer**:
#     - how many of these small datasets do we have (in this training dataset)?
#     - how many QA points per dataset?
#     - how to preprocess this data for model training?

# %%
# We create simple counts and lists to store all counts for calculations of the averages.
par_count = 0
par_avg = []
qas_count = 0
qas_avg = []
impossible_qas = 0

for d in train['data']:
    count = len(d['paragraphs'])
    par_count += count
    par_avg.append(count)
    for p in d['paragraphs']: 
        count = len(p['qas'])
        for qa in p['qas']:
            if qa['is_impossible'] == True:
                impossible_qas +=1
        qas_count += count
        qas_avg.append(count)
        

print(f"We have data on {len(train['data'])} articles, containing {par_count} combined paragraphs, \
containing {qas_count} combined Q&A pairs, {impossible_qas} of which ({(impossible_qas / qas_count):.2%}) are classified as 'impossible to answer';")
print()
print(f"On average, we have {np.average(par_avg):.1f} paragraphs per article and {np.average(qas_avg):.1f} Q&A pairs per paragraph.")
# Out:
# We have data on 442 articles, containing 19035 combined paragraphs, containing 130319 combined Q&A pairs, 43498 of which (33.38%) are classified as 'impossible to answer';
#
# On average, we have 43.1 paragraphs per article and 6.8 Q&A pairs per paragraph.
